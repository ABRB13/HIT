# %%
import pygame 

pygame.init()


screen = pygame.display.set_mode((500, 500))

running = True

while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    screen.fill((255,255,255)) #rgb
    
    pygame.draw.circle(screen, (0, 255, 255), (250, 250), 75)
    
    pygame.display.flip()

pygame.quit()

# %%
import pygame 

from pygame.locals import (
K_UP,
K_DOWN,
K_LEFT,
K_RIGHT,
K_ESCAPE,
KEYDOWN,
QUIT)

pygame.init()

screen_width = 800
screen_height = 600

screen = pygame.display.set_mode((screen_width, screen_height))

# %%
#game loop

screen_width = 800
screen_height = 600

running = True

while running:
    for event in pygame.event.get():
        if event.type == KEYDOWN:
            
            #
            if event.key == K_ESCAPE:
                
                running = False
        elif event.type == QUIT:
            running = False 
            
    screen.fill((255,255,255)) #rgb
    
    surface = pygame.Surface((50,50)) #width, heith
    surf.fill((0,0,0))
    rect = surf.get_rect()
    screen.blit(surf, (screen_width/2, screen_height/2))
    pygame.display.flip()
    
    
    pygame.draw.circle(screen, (0, 255, 255), (250, 250), 75)
    
    pygame.display.flip()

pygame.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18364\3052578469.py in <module>
#       7
#       8 while running:
# ----> 9     for event in pygame.event.get():
#      10         if event.type == KEYDOWN:
#      11
#
# NameError: name 'pygame' is not defined

# %%
import pygame 
import random

from pygame.locals import (
K_UP,
K_DOWN,
K_LEFT,
K_RIGHT,
K_ESCAPE,
KEYDOWN,
RLEACCEL,
QUIT)

pygame.init()

screen_width = 800
screen_height = 600

screen = pygame.display.set_mode((screen_width, screen_height))
pygame.display.set_caption("Game1")

addenemy = pygame.USEREVENT + 1
pygame.time.set_timer(addenemy, 250) #ms

addcloud = pygame.USEREVENT + 2
pygame.time.set_timer(addcloud, 2000)

pygame.mixer.music.load('deep.mp3')
pygame.mixer.music.play(loops=-1)

move_up_sound = pygame.mixer.Sound('fight.mp3')
move_down_sound = pygame.mixer.Sound('fight.mp3')

collision_sound = pygame.mixer.Sound('fight.mp3')




class Player(pygame.sprite.Sprite):
    def __init__(self):
        super(Player, self).__init__()
        self.surf = pygame.image.load("jey.png")
        self.surf.set_colorkey((255,255,255), RLEACCEL)
        self.rect = self.surf.get_rect()
    
    def update(self, pressed_keys):
        if pressed_keys[K_UP]:
            self.rect.move_ip(0, -5)
            move_up_sound.play()
        if pressed_keys[K_DOWN]:
            self.rect.move_ip(0, 5)
            move_down_sound.play()
        if pressed_keys[K_LEFT]:
            self.rect.move_ip(-5, 0)
        if pressed_keys[K_RIGHT]:
            self.rect.move_ip(5, 0)
            
            
        if self.rect.top < 0:
            self.rect.top = 0
        if self.rect.bottom > screen_height:
            self.rect.bottom = screen_height
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > screen_width:
            self.rect.right = screen_width
            



class Enemy(pygame.sprite.Sprite):
    def __init__(self):
        super(Enemy, self).__init__()
        self.surf = pygame.image.load('mis.png').convert()
        self.surf.set_colorkey((255,255,255), RLEACCEL)
        self.rect = self.surf.get_rect(center = (random.randint(screen_width + 20, screen_width + 100), random.randint(0, screen_height)))
        
            
        self.speed = random.randint(1, 4)
    
    def update(self):
        self.rect.move_ip(-self.speed, 0)
        if self.rect.right < 0:
            self.kill()
            
class Cloud(pygame.sprite.Sprite):
    def __init__(self):
        super(Cloud, self).__init__()
        self.surf = pygame.image.load('cloud.png').convert()
        self.surf.set_colorkey((255,255,255), RLEACCEL)
        self.rect = self.surf.get_rect(
        center = (
        random.randint(screen_width + 20, screen_width + 100),
        random.randint(0, screen_height)))
    def update(self):
        self.rect.move_ip(-5,0)
        if self.rect.right < 0:
            self.kill()

            
player = Player()

all_sprites = pygame.sprite.Group()
enemies = pygame.sprite.Group()
clouds = pygame.sprite.Group()
all_sprites.add(player)

clock = pygame.time.Clock()

running = True 

while running:
    for event in pygame.event.get():
        if event.type == QUIT:
            running = False
        elif event.type == addenemy:
            new_enemy = Enemy()
            enemies.add(new_enemy)
            all_sprites.add(new_enemy)
        elif event.type == addcloud:
            new_cloud = Cloud()
            clouds.add(new_cloud)
            all_sprites.add(new_cloud)
            
    pressed_keys = pygame.key.get_pressed()
    player.update(pressed_keys)
    enemies.update()
    clouds.update()
    screen.fill((135,206,250))
    #rect = surf.get_rect()
    
    for entity in all_sprites:
        screen.blit(entity.surf, entity.rect)
        
    if pygame.sprite.spritecollideany(player,enemies):
        player.kill()
        move_up_sound.stop()
        move_down_sound.stop()
        collision_sound.stop()
        running = False
    
    pygame.display.flip()
    clock.tick(50)
    
pygame.mixer.music.stop()

pygame.quit()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#sprite groups

# %%
#user inputs

# %%
addcloud = pygame.USEREVENT + 2
pygame.time.set_timer(addcloud, 1000)

clouds = pygame.sprite.Group()
allsprites.add(clouds)

# %%
if pygame.sprite.spritecollideany(player, enemies):
    player.kill()
    running = False

# %%
#pygame image module
